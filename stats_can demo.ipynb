# %% [markdown]
# # Demo notebook for stats_can package
#
# API documentation for StatsCan can be found here: https://www.statcan.gc.ca/eng/developers/wds
#
# If you're looking for Table/Vector IDs to use in the app you can find them through this: https://www150.statcan.gc.ca/n1/en/type/data
#
# Anaconda package here: https://anaconda.org/ian.e.preston/stats_can
#
# This notebook will provide an overview of the key functionality of the stats_can python package

# %%
import stats_can
import datetime as dt
import pandas as pd
import h5py
import json

# %% [markdown]
# The first thing we can do is retrieve a list of tables/vectors that have been updated today:

# %%
changed_series = stats_can.get_changed_series_list()
# show just the first few
changed_series[0:min(5, len(changed_series))]
# Out:
# [{'responseStatusCode': 0,
#   'vectorId': 41838396,
#   'productId': 10100142,
#   'coordinate': '1.6.0.0.0.0.0.0.0.0',
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'vectorId': 52300164,
#   'productId': 34100158,
#   'coordinate': '8.0.0.0.0.0.0.0.0.0',
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'vectorId': 52300189,
#   'productId': 34100159,
#   'coordinate': '5.0.0.0.0.0.0.0.0.0',
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'vectorId': 1000149052,
#   'productId': 12100089,
#   'coordinate': '1.2.2.1.20.41.0.0.0.0',
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'vectorId': 1000148893,
#   'productId': 12100089,
#   'coordinate': '1.2.1.1.133.41.0.0.0.0',
#   'releaseTime': '2018-08-20T08:30'}]

# %%
# This takes a date argument or defaults to today
changed_tables = stats_can.get_changed_cube_list()
# Show just the first few
changed_tables[0:min(5, len(changed_tables))]
# Out:
# [{'responseStatusCode': 0,
#   'productId': 13100457,
#   'releaseTime': '2018-08-20T13:36'},
#  {'responseStatusCode': 0,
#   'productId': 33100036,
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'productId': 12100089,
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'productId': 10100136,
#   'releaseTime': '2018-08-20T08:30'},
#  {'responseStatusCode': 0,
#   'productId': 10100139,
#   'releaseTime': '2018-08-20T08:30'}]

# %% [markdown]
# MetaData on tables can also be retrieved:
# Note that the package makes some minimal efforts to parse vector/cube/table names into the format accepted by StatsCan

# %%
table_name = '10-10-0106-01'
table_meta = stats_can.get_cube_metadata(table_name)
table_meta
# Out:
# [{'responseStatusCode': 0,
#   'productId': '10100106',
#   'cansimId': '176-0003',
#   'cubeTitleEn': 'Consumer Price Index (CPI) statistics, alternative measures, unadjusted and seasonally adjusted, Bank of Canada',
#   'cubeTitleFr': "Statistiques de l'Indice des prix à la consommation (IPC), mesures alternatives, non désaisonnalisées et désaisonnalisées, Banque du Canada",
#   'cubeStartDate': '1979-11-01',
#   'cubeEndDate': '2018-07-01',
#   'nbSeriesCube': 18,
#   'nbDatapointsCube': 4925,
#   'archiveStatusCode': '2',
#   'archiveStatusEn': 'CURRENT - a cube available to the public and that is current',
#   'archiveStatusFr': 'ACTIF - un cube qui est disponible au public et qui est toujours mise a jour',
#   'subjectCode': ['1004', '1802'],
#   'surveyCode': ['7502'],
#   'dimension': [{'dimensionPositionId': 1,
#     'dimensionNameEn': 'Geography',
#     'dimensionNameFr': 'Géographie',
#     'hasUom': False,
#     'member': [{'memberId': 1,
#       'parentMemberId': None,
#       'memberNameEn': 'Canada',
#       'memberNameFr': 'Canada',
#       'classificationCode': '11124',
#       'classificationTypeCode': '1',
#       'geoLevel': 0,
#       'vintage': 2016,
#       'terminated': 0,
#       'memberUomCode': None}]},
#    {'dimensionPositionId': 2,
#     'dimensionNameEn': 'Alternative measures',
#     'dimensionNameFr': 'Mesures alternatives',
#     'hasUom': True,
#     'member': [{'memberId': 1,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding the effect of indirect taxes',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors effet des impôts indirects',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 171},
#      {'memberId': 2,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding food, energy and the effect of indirect taxes',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors alimentation, énergie et effet des impôts indirects',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 171},
#      {'memberId': 3,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding the effect of indirect taxes, seasonally adjusted',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors effet des impôts indirects, désaisonnalisé',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 171},
#      {'memberId': 4,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding food, energy and the effect of indirect taxes, seasonally adjusted',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors alimentation, énergie et effet des impôts indirects, désaisonnalisé',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 171},
#      {'memberId': 5,
#       'parentMemberId': None,
#       'memberNameEn': 'Contribution of indirect taxes to annual growth rate of the Consumer Price Index (CPI)',
#       'memberNameFr': "Contribution des impôts indirects à la croissance annuelle d'Indice des prix à la consommation (IPC)",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 239},
#      {'memberId': 6,
#       'parentMemberId': None,
#       'memberNameEn': 'Contribution of indirect taxes to annual growth rate of the Consumer Price Index (CPI) excluding food and energy',
#       'memberNameFr': "Contribution des impôts indirects à la croissance annuelle d'Indice des prix à la consommation (IPC) hors alimentation et énergie",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 239},
#      {'memberId': 7,
#       'parentMemberId': None,
#       'memberNameEn': 'Contribution of indirect taxes to monthly growth rate of the Consumer Price Index (CPI)',
#       'memberNameFr': "Contribution des impôts indirects à la croissance mensuelle d'Indice des prix à la consommation (IPC)",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 239},
#      {'memberId': 8,
#       'parentMemberId': None,
#       'memberNameEn': 'Contribution of indirect taxes to monthly growth rate of the Consumer Price Index (CPI) excluding food and energy',
#       'memberNameFr': "Contribution des impôts indirects à la croissance mensuelle d'Indice des prix à la consommation (IPC) hors alimentation et énergie",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 239},
#      {'memberId': 9,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding 8 of the most volatile components and indirect taxes (CPIX)',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) moins les 8 composantes les plus volatiles et impôts indirects (IPCX)',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 171},
#      {'memberId': 10,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) inversely weighted by volatility and is adjusted to exclude the effect of changes in indirect taxes (CPIW) (year-over-year percent change)',
#       'memberNameFr': "Indice des prix à la consommation (IPC) avec pondération inverse par volatilité et corrigé de l'effet des modifications des impôts indirects (IPCP) (taux de variation d'une année à l'autre)",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 0,
#       'memberUomCode': 239},
#      {'memberId': 11,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding the effect of indirect taxes',
#       'memberNameFr': "Indice des prix à la consommation (IPC) hors effet d'impôts indirects",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 173},
#      {'memberId': 12,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding food, energy and the effect of indirect taxes',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors alimentation, énergie et effet des impôts indirects',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 173},
#      {'memberId': 13,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding the effect of indirect taxes, seasonally adjusted',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors effet des impôts indirects, désaisonnalisé',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 173},
#      {'memberId': 14,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding food, energy and the effect of indirect taxes, seasonally adjusted',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors alimentation, énergie et effet des impôts indirects, désaisonnalisé',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 173},
#      {'memberId': 15,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding the effect of indirect taxes',
#       'memberNameFr': "Indice des prix à la consommation (IPC) hors effet d'impôts indirects",
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 178},
#      {'memberId': 16,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding food, energy and the effect of indirect taxes',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors alimentation, énergie et effet des impôts indirects',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 0,
#       'memberUomCode': 178},
#      {'memberId': 17,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding the effect of indirect taxes, seasonally adjusted',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors effet des impôts indirects, désaisonnalisé',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 1,
#       'memberUomCode': 178},
#      {'memberId': 18,
#       'parentMemberId': None,
#       'memberNameEn': 'Consumer Price Index (CPI) excluding food, energy and the effect of indirect taxes, seasonally adjusted',
#       'memberNameFr': 'Indice des prix à la consommation (IPC) hors alimentation, énergie et effet des impôts indirects, désaisonnalisé',
#       'classificationCode': None,
#       'classificationTypeCode': None,
#       'geoLevel': None,
#       'vintage': None,
#       'terminated': 0,
#       'memberUomCode': 178}]}],
#   'footnote': [{'footnoteId': 1,
#     'footnotesEn': 'The Bank of Canada is no longer publishing the Consumer Price Index (CPI) excluding 8 of the most volatile components and indirect taxes (CPIX) (index, 1992=100). This information is available in archived CANSIM table 326-0001, core Consumer Price Index (CPI) (Bank of Canada definition).',
#     'footnotesFr': "La Banque du Canada ne publie plus l'Indice des prix à la consommation (IPC) excluant 8 des composantes les plus volatiles et les impôts indirects (IPCX) (indice, 1992=100). Ces données sont stockées dans le tableau CANSIM 326-0001 archivé, Indice des prix à la consommation (IPC) de référence (définition de la Banque du Canada).",
#     'link': {'footnoteId': 1, 'dimensionPositionId': 0, 'memberId': 0}}],
#   'correction': None}]

# %% [markdown]
# You can perform a similar operation for individual or lists of vectors

# %%
vectors = ['v74804', 'v41692457']
stats_can.get_series_info_from_vector(vectors)
# Out:
# [{'responseStatusCode': 0,
#   'productId': 18100004,
#   'coordinate': '23.287.0.0.0.0.0.0.0.0',
#   'vectorId': 41692457,
#   'frequencyCode': 6,
#   'scalarFactorCode': 0,
#   'decimals': 1,
#   'terminated': 0,
#   'SeriesTitleEn': 'Alberta;All-items excluding energy',
#   'SeriesTitleFr': "Alberta;Ensemble excluant l'énergie",
#   'memberUomCode': 17},
#  {'responseStatusCode': 0,
#   'productId': 23100216,
#   'coordinate': '1.2.1.0.0.0.0.0.0.0',
#   'vectorId': 74804,
#   'frequencyCode': 6,
#   'scalarFactorCode': 0,
#   'decimals': 0,
#   'terminated': 0,
#   'SeriesTitleEn': 'Canada;Total non-intermodal traffic loaded;Number of rail cars',
#   'SeriesTitleFr': 'Canada;Total, trafic non-intermodal chargé;Nombre de wagons',
#   'memberUomCode': 223}]

# %% [markdown]
# Tables for vectors is mostly a helper method, if you have a list of vectors that you're interested in, it will return a dictionary mapping what tables those vectors are in, as well as return a list of all tables needed to retrieve those vectors

# %%
stats_can.get_tables_for_vectors(vectors)
# Out:
# {41692457: '18100004',
#  74804: '23100216',
#  'all_tables': ['23100216', '18100004']}

# %% [markdown]
# Similar deal for table subsets for vectors, it returns a dictionary with keys of table names mapped to a list of vectors contained in those tables

# %%
stats_can.table_subsets_from_vectors(vectors)
# Out:
# {'23100216': [74804], '18100004': [41692457]}

# %% [markdown]
# Vectors to df will take a list of vectors and either an argument specifying the number of most recent periods to retrieve, or a start and end date for the period in which the data was released. Note that release date is not the same as the reference period, which is the date index you'll see in the returned dataframe

# %%
df_n = stats_can.vectors_to_df(vectors, periods=5)
df_n
# Out:
#             v41692457    v74804
# refPer
# 2018-01-01        NaN  291408.0
# 2018-02-01        NaN  263194.0
# 2018-03-01      137.8  314121.0
# 2018-04-01      137.7  301073.0
# 2018-05-01      138.0  306822.0
# 2018-06-01      138.2       NaN
# 2018-07-01      138.7       NaN

# %%
df_d = stats_can.vectors_to_df(vectors, start_release_date=dt.date(2018, 1, 1), end_release_date=dt.date(2018, 8, 20))
df_d.head()
# Out:
#             v41692457  v74804
# refPer
# 2013-01-01      124.5     NaN
# 2013-02-01      125.1     NaN
# 2013-03-01      125.5     NaN
# 2013-04-01      125.8     NaN
# 2013-05-01      126.3     NaN

# %% [markdown]
# The package has some methods exposed to download zipped csv files of entire tables and read them into dataframes, but I've got an updated implementation that just uses those methods to download tables and read them into an hdf5 file (https://support.hdfgroup.org/HDF5/) which ends up being way faster. For one particularly large table my machine ran about 2.5 minutes to load a zipped csv of the table into a dataframe, whereas reading it from hdf5 took 30 seconds. If you're going to be accessing the tables with an regularity it's totally worth using hdf5

# %%
# can also include arguments for where to store the h5 file and what to name it
tables = ['27100022', '18100204']
stats_can.tables_to_h5(tables)

# %% [markdown]
# The h5_update_tables function will compare the metadata associated with tables in an h5 file, compare it to the metadata from the StatsCan website, download any out of date tables and read them into the h5 file. There's no output so I won't call the method here, but the syntax is:
# stats_can.h5_update_tables(h5file='name_of_file.h5', path='path_to_h5_file')

# %% [markdown]
# Having added a couple tables into the h5 file we can read them out to a dataframe using the pandas read_hdf method
#
# I should probably add a helper method that creates the key name from a parsed table

# %%
df_tbl = pd.read_hdf('stats_can.h5', key='table_27100022')
df_tbl.head()
# Out:
#     REF_DATE     GEO           DGUID        Performing sector  \
# 0 2000-01-01  Canada  2016A000011124  Total performing sector
# 1 2000-01-01  Canada  2016A000011124  Total performing sector
# 2 2000-01-01  Canada  2016A000011124  Total performing sector
# 3 2000-01-01  Canada  2016A000011124  Total performing sector
# 4 2000-01-01  Canada  2016A000011124  Total performing sector
#
#   Occupational category                   Type of science     UOM UOM_ID  \
# 0       Total personnel                    Total sciences  Number    223
# 1       Total personnel  Natural sciences and engineering  Number    223
# 2       Total personnel    Social sciences and humanities  Number    223
# 3           Researchers                    Total sciences  Number    223
# 4           Researchers  Natural sciences and engineering  Number    223
#
#   SCALAR_FACTOR SCALAR_ID     VECTOR COORDINATE     VALUE STATUS SYMBOL  \
# 0        units          0  v54329358    1.1.1.1  167940.0    NaN    NaN
# 1        units          0  v54329359    1.1.1.2  147290.0    NaN    NaN
# 2        units          0  v54329360    1.1.1.3   20650.0    NaN    NaN
# 3        units          0  v54329361    1.1.2.1  107900.0    NaN    NaN
# 4        units          0  v54329362    1.1.2.2   91590.0    NaN    NaN
#
#   TERMINATED DECIMALS
# 0        NaN        0
# 1          t        0
# 2          t        0
# 3        NaN        0
# 4          t        0

# %% [markdown]
# The local metadata can be retrieved, but you have to use h5py so the syntax is a little different, again, should probably add a helper method here

# %%
with h5py.File('stats_can.h5', 'r') as f:
    table_json = json.loads(f['json_27100022'][()])
table_json
# Out:
# {'responseStatusCode': 0,
#  'productId': '27100022',
#  'cansimId': '358-0159',
#  'cubeTitleEn': 'Personnel engaged in research and development by performing sector and occupational category',
#  'cubeTitleFr': "Personnel affecté à la recherche et au développement selon le secteur d'exécution et la catégorie professionnelle",
#  'cubeStartDate': '2000-01-01',
#  'cubeEndDate': '2015-01-01',
#  'nbSeriesCube': 68,
#  'nbDatapointsCube': 1088,
#  'archiveStatusCode': '2',
#  'archiveStatusEn': 'CURRENT - a cube available to the public and that is current',
#  'archiveStatusFr': 'ACTIF - un cube qui est disponible au public et qui est toujours mise a jour',
#  'subjectCode': ['2702'],
#  'surveyCode': ['5193'],
#  'dimension': [{'dimensionPositionId': 1,
#    'dimensionNameEn': 'Geography',
#    'dimensionNameFr': 'Géographie',
#    'hasUom': False,
#    'member': [{'memberId': 1,
#      'parentMemberId': None,
#      'memberNameEn': 'Canada',
#      'memberNameFr': 'Canada',
#      'classificationCode': '11124',
#      'classificationTypeCode': '1',
#      'geoLevel': 0,
#      'vintage': 2016,
#      'terminated': 0,
#      'memberUomCode': None}]},
#   {'dimensionPositionId': 2,
#    'dimensionNameEn': 'Performing sector',
#    'dimensionNameFr': "Secteur d'exécution",
#    'hasUom': False,
#    'member': [{'memberId': 1,
#      'parentMemberId': None,
#      'memberNameEn': 'Total performing sector',
#      'memberNameFr': "Total, secteurs d'exécution",
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 2,
#      'parentMemberId': 1,
#      'memberNameEn': 'Federal government',
#      'memberNameFr': 'Administrations fédérale',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 3,
#      'parentMemberId': 1,
#      'memberNameEn': 'Provincial government',
#      'memberNameFr': 'Administrations provinciales',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 4,
#      'parentMemberId': 1,
#      'memberNameEn': 'Business enterprise',
#      'memberNameFr': 'Entreprises commerciales',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 5,
#      'parentMemberId': 1,
#      'memberNameEn': 'Higher education',
#      'memberNameFr': 'Enseignement supérieur',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 6,
#      'parentMemberId': 1,
#      'memberNameEn': 'Private non-profit',
#      'memberNameFr': 'Organismes privés sans but lucratif',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None}]},
#   {'dimensionPositionId': 3,
#    'dimensionNameEn': 'Occupational category',
#    'dimensionNameFr': 'Catégorie professionnelle',
#    'hasUom': False,
#    'member': [{'memberId': 1,
#      'parentMemberId': None,
#      'memberNameEn': 'Total personnel',
#      'memberNameFr': 'Total de personnel',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 2,
#      'parentMemberId': 1,
#      'memberNameEn': 'Researchers',
#      'memberNameFr': 'Chercheurs',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 3,
#      'parentMemberId': 1,
#      'memberNameEn': 'Technicians',
#      'memberNameFr': 'Techniciens',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None},
#     {'memberId': 4,
#      'parentMemberId': 1,
#      'memberNameEn': 'Support staff',
#      'memberNameFr': 'Personnel de soutien',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': None}]},
#   {'dimensionPositionId': 4,
#    'dimensionNameEn': 'Type of science',
#    'dimensionNameFr': 'Type de science',
#    'hasUom': True,
#    'member': [{'memberId': 1,
#      'parentMemberId': None,
#      'memberNameEn': 'Total sciences',
#      'memberNameFr': 'Total des sciences',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 0,
#      'memberUomCode': 223},
#     {'memberId': 2,
#      'parentMemberId': 1,
#      'memberNameEn': 'Natural sciences and engineering',
#      'memberNameFr': 'Sciences naturelles et génie',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 1,
#      'memberUomCode': 223},
#     {'memberId': 3,
#      'parentMemberId': 1,
#      'memberNameEn': 'Social sciences and humanities',
#      'memberNameFr': 'Sciences sociales et humaines',
#      'classificationCode': None,
#      'classificationTypeCode': None,
#      'geoLevel': None,
#      'vintage': None,
#      'terminated': 1,
#      'memberUomCode': 223}]}],
#  'footnote': [{'footnoteId': 1,
#    'footnotesEn': 'Personnel counts are reported as full-time equivalents (rounded to the nearest 10). Due to rounding, components may not add to the totals.',
#    'footnotesFr': "Le personnel est reporté en équivalent temps plein (nombres arrondis à la dizaine).  En raison de l'arrondissement des données, les totaux ne correspondent pas toujours à l'addition de leurs composantes.",
#    'link': {'footnoteId': 1, 'dimensionPositionId': 0, 'memberId': 0}},
#   {'footnoteId': 5,
#    'footnotesEn': 'From 2014 onwards, the Researchers category includes on-site research and development consultants and contractors for the private non-profit sector and business enterprise sector.',
#    'footnotesFr': 'À partir de 2014, la catégorie des chercheurs inclue les conseillers et entrepreneurs des organismes privés sans but lucratif et des entreprises commerciales qui interviennent sur place en recherche et développement.',
#    'link': {'footnoteId': 5, 'dimensionPositionId': 0, 'memberId': 0}},
#   {'footnoteId': 3,
#    'footnotesEn': 'Provincial government data includes provincial research organizations data. Provincial research organizations data are in natural sciences and engineering only.',
#    'footnotesFr': 'Les données du secteur des administrations provinciales inclut les organismes de recherche provinciaux. Les données des organismes de recherche provinciaux sont pour les sciences naturelles et génie seulement.',
#    'link': {'footnoteId': 3, 'dimensionPositionId': 2, 'memberId': 3}},
#   {'footnoteId': 4,
#    'footnotesEn': "Private non-profit organization's personnel counts may fluctuate due to these organization's intramural research and development activities",
#    'footnotesFr': 'Le personnel des organismes privés sans but lucratif peut fluctuer en raison des acitivités de recherche et développement intramuros de ces organisations.',
#    'link': {'footnoteId': 4, 'dimensionPositionId': 2, 'memberId': 6}}],
#  'correction': None}

# %% [markdown]
# Can also see what keys are in the file, again helpers for json and df keys are on my todo

# %%
with h5py.File('stats_can.h5', 'r') as f:
    keys = [key for key in f.keys()]
keys
# Out:
# ['json_18100204', 'json_27100022', 'table_18100204', 'table_27100022']
